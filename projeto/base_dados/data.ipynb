# %% [markdown]
# ### Importação de Bibliotecas e dataframes

# %%
import pandas as pd
import numpy as np
print('Bibliotecas carregadas com sucesso')
# Out:
# Bibliotecas carregadas com sucesso

# %%
# --- Carregamento da base de dados original --- #

df_movies = pd.read_csv('top_1000_imdb_movies.csv')

# %% [markdown]
# ### Análise primária ao dataframe

# %%
# --- Primeiras 5 linhas do DataFrame --- #

# Visualiza-se a forma como estão organizados os dados.
   
df_movies.head()
# Out:
#    Unnamed: 0                Movie Name Year of Release  Watch Time  \
# 0           0  The Shawshank Redemption            1994         142
# 1           1             The Godfather            1972         175
# 2           2           The Dark Knight            2008         152
# 3           3          Schindler's List            1993         195
# 4           4              12 Angry Men            1957          96
#
#    Movie Rating                                        Description
# 0           9.3  Over the course of several years, two convicts...
# 1           9.2  Don Vito Corleone, head of a mafia family, dec...
# 2           9.0  When the menace known as the Joker wreaks havo...
# 3           9.0  In German-occupied Poland during World War II,...
# 4           9.0  The jury in a New York City murder trial is fr...

# %%
# --- Informações gerais acerca do DataFrame --- #

# Destaque aqui para ausência de valores nulos á primeira vista e pelo tipo de dados atribuido (object) á coluna 'Year of Release'.

df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1000 non-null   int64
#  1   Movie Name       1000 non-null   object
#  2   Year of Release  1000 non-null   object
#  3   Watch Time       1000 non-null   int64
#  4   Movie Rating     1000 non-null   float64
#  5   Description      1000 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 47.0+ KB

# %%
# --- Informações sobre as colunas não numéricas --- #

# Nota-se que na coluna Movie Name existem 997 valores únicos em 1000 possíveis, denotando-se que poderão haver valores duplicados nesta coluna, sendo que mais para a frente terá que ser visualizado.

df_movies.describe(exclude='number')
# Out:
#         Movie Name Year of Release  \
# count         1000            1000
# unique         997             123
# top     Drishyam 2            2014
# freq             2              28
#
#                                               Description
# count                                                1000
# unique                                               1000
# top     Over the course of several years, two convicts...
# freq                                                    1

# %% [markdown]
# ### Manipulação do dataframe

# %%
# --- Criação do dataframe para manipulação --- #

df_manipulado = df_movies.copy()

# %% [markdown]
# #### Tratamento de dados

# %% [markdown]
# ##### Coluna 'Year of Release'

# %%
# --- Verificação dos dados na coluna ano de estreia (Year of Release) --- #

# Tomou-se a decisão devido ao pandas ter considerado o Year of Release como 'object' e não como 'int', o que pode indicar que há valores que não terão apenas números. 
# Nota-se que existem após a conversão, apenas 965 valores em 1000 que foram corretamente convertidos, sendo os restantes preenchidos com valor nulo.

df_manipulado['Ano'] = pd.to_numeric(df_manipulado['Year of Release'], errors= 'coerce')
df_manipulado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1000 non-null   int64
#  1   Movie Name       1000 non-null   object
#  2   Year of Release  1000 non-null   object
#  3   Watch Time       1000 non-null   int64
#  4   Movie Rating     1000 non-null   float64
#  5   Description      1000 non-null   object
#  6   Ano              965 non-null    float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 54.8+ KB

# %%
# --- Inspeção de nulos na coluna 'Ano' --- #

nulos = df_manipulado[df_manipulado['Ano'].isna()]
nulos
# Out:
#      Unnamed: 0          Movie Name Year of Release  Watch Time  Movie Rating  \
# 59           59                  96         II 2018         158           8.5
# 65           65               Joker          I 2019         122           8.4
# 77           77                Coco          I 2017         105           8.4
# 163         163          The Father          I 2020          97           8.2
# 232         232          Inside Out          I 2015          95           8.1
# 240         240           Spotlight          I 2015         129           8.1
# 244         244                Rush          I 2013         123           8.1
# 246         246                Room          I 2015         118           8.1
# 332         332                Pink        III 2016         136           8.1
# 350         350        The Revenant          I 2015         156           8.0
# 395         395               Mommy          I 2014         139           8.0
# 444         444         Mar adentro          I 2004         126           8.0
# 476         476             Arrival         II 2016         116           7.9
# 501         501              Wonder          I 2017         113           7.9
# 509         509             Boyhood          I 2014         165           7.9
# 543         543          The Artist          I 2011         100           7.9
# 592         592       No Man's Land          I 2001          98           7.9
# 596         596                Baby          I 2015         159           7.9
# 604         604               Drive          I 2011         100           7.8
# 609         609          About Time          I 2013         123           7.8
# 615         615             Get Out          I 2017         104           7.8
# 640         640               Close          I 2022         104           7.8
# 643         643               Taken          I 2008          90           7.8
# 660         660         The Fighter          I 2010         116           7.8
# 670         670            The Fall          I 2006         117           7.8
# 706         706                Once          I 2007          86           7.8
# 711         711               Pride          I 2014         119           7.8
# 760         760            Aftersun         II 2022         102           7.7
# 786         786           Apollo 13          I 1995         140           7.7
# 812         812               Crash          I 2004         112           7.7
# 833         833             Flipped          I 2010          90           7.7
# 838         838                 Ray          I 2004         152           7.7
# 950         950  Hell or High Water         II 2016         102           7.6
# 963         963         After Hours          I 1985          97           7.6
# 968         968           Searching        III 2018         102           7.6
#
#                                            Description  Ano
# 59   Two high school sweethearts meet at a reunion ...  NaN
# 65   The rise of Arthur Fleck, from aspiring stand-...  NaN
# 77   Aspiring musician Miguel, confronted with his ...  NaN
# 163  A man refuses all assistance from his daughter...  NaN
# 232  After young Riley is uprooted from her Midwest...  NaN
# 240  The true story of how the Boston Globe uncover...  NaN
# 244  The merciless 1970s rivalry between Formula On...  NaN
# 246  A little boy is held captive in a room with hi...  NaN
# 332  When three young women are implicated in a cri...  NaN
# 350  A frontiersman on a fur trading expedition in ...  NaN
# 395  A widowed single mother, raising her violent s...  NaN
# 444  The factual story of Spaniard Ramon Sampedro, ...  NaN
# 476  A linguist works with the military to communic...  NaN
# 501  Based on the New York Times bestseller, this m...  NaN
# 509  The life of Mason, from early childhood to his...  NaN
# 543  An egomaniacal film star develops a relationsh...  NaN
# 592  Bosnia and Herzegovina during 1993 at the time...  NaN
# 596  An elite counter-intelligence unit learns of a...  NaN
# 604  A mysterious Hollywood action film stuntman ge...  NaN
# 609  At the age of 21, Tim discovers he can travel ...  NaN
# 615  A young African-American visits his White girl...  NaN
# 640  The intense friendship between two thirteen-ye...  NaN
# 643  A retired CIA agent travels across Europe and ...  NaN
# 660  Based on the story of Micky Ward, a fledgling ...  NaN
# 670  In a hospital on the outskirts of 1920s Los An...  NaN
# 706  A modern-day musical about a busker and an imm...  NaN
# 711  U.K. gay activists work to help miners during ...  NaN
# 760  Sophie reflects on the shared joy and private ...  NaN
# 786  NASA must devise a strategy to return Apollo 1...  NaN
# 812  Los Angeles citizens with vastly separate live...  NaN
# 833  Two eighth-graders start to have feelings for ...  NaN
# 838  The story of the life and career of the legend...  NaN
# 950  Toby is a divorced father who's trying to make...  NaN
# 963  An ordinary word processor has the worst night...  NaN
# 968  After his teenage daughter goes missing, a des...  NaN

# %%
# --- Tratamento dos valores na coluna 'Year of Release' após ver nulos na coluna Ano --- #

# Após se verificar a razão pela qual os valores não conseguiram ser convertidos para inteiro, aplicou-se uma função para tratar os mesmos, dado que os valores que deram nulo na conversão têm todos o mesmo problema, o de ter um caracter antes do ano.

df_manipulado['Year of Release'] = df_manipulado['Year of Release']. apply(lambda x: x.split()[-1])

# %%
# --- Conversão dos valores em 'Year of Release' para inteiro --- #

df_manipulado['Year of Release'] = pd.to_numeric(df_manipulado['Year of Release'], errors='coerce')

# %% [markdown]
# ##### Verificação dos dados após tratamento

# %%
# --- Verificação dos tipos de dados das colunas --- #

# Verificou-se que, após a conversão dos dados não existem valores nulos na coluna 'Year of Release'.

df_manipulado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1000 non-null   int64
#  1   Movie Name       1000 non-null   object
#  2   Year of Release  1000 non-null   int64
#  3   Watch Time       1000 non-null   int64
#  4   Movie Rating     1000 non-null   float64
#  5   Description      1000 non-null   object
#  6   Ano              965 non-null    float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 54.8+ KB

# %% [markdown]
# ##### Eliminação das colunas excedentárias

# %%
# --- Eliminação da coluna 'Unnamed' e 'Ano'. --- #

df_manipulado = df_manipulado.drop(['Unnamed: 0', 'Ano'], axis = 1)

# %% [markdown]
# ##### Diminuição do tamanho na memória dos dados

# %%
# --- Seleção das colunas do tipo inteiro --- #

n_int = df_manipulado.select_dtypes('integer').columns
n_int
# Out:
# Index(['Year of Release', 'Watch Time'], dtype='object')

# %%
# --- Diminuição do tamanho em memória --- #

df_manipulado[n_int] = df_manipulado[n_int].apply(pd.to_numeric, downcast = 'integer')
df_manipulado['Movie Rating'] = pd.to_numeric(df_manipulado['Movie Rating'], downcast='float')

# %%
# --- Dataframe após operação --- #

# Espaço na memória passou de 39.2 KB para 23.6 KB

df_manipulado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Movie Name       1000 non-null   object
#  1   Year of Release  1000 non-null   int16
#  2   Watch Time       1000 non-null   int16
#  3   Movie Rating     1000 non-null   float32
#  4   Description      1000 non-null   object
# dtypes: float32(1), int16(2), object(2)
# memory usage: 23.6+ KB

# %% [markdown]
# ##### Coluna 'Movie Name'

# %%
# --- Verificação de valores duplicados na coluna 'Movie Name' --- #

# Verificou-se a diferença entre os valores que se encontram duplicados. As diferenças entre eles são significativas, tendo apenas em comum o seu nome. Porém para não haver conflito futuro na pesquisa, opta-se por eliminar os segundos duplicados.

duplicados = df_manipulado[df_manipulado.duplicated('Movie Name', keep= False)]
duplicados
# Out:
#      Movie Name  Year of Release  Watch Time  Movie Rating  \
# 90   Drishyam 2             2021         152           8.4
# 102    Scarface             1983         170           8.3
# 139    Drishyam             2013         160           8.3
# 179  Drishyam 2             2022         140           8.2
# 189    Drishyam             2015         163           8.2
# 905    Scarface             1932          93           7.7
#
#                                            Description
# 90   A gripping tale of an investigation and a fami...
# 102  In 1980 Miami, a determined Cuban immigrant ta...
# 139  A man goes to extreme lengths to save his fami...
# 179  A gripping tale of an investigation and a fami...
# 189  Desperate measures are taken by a man who trie...
# 905  An ambitious and nearly insane violent gangste...

# %%
# Eliminação dos duplicados na coluna 'Movie Name', mantendo os primeiros registos.

df_manipulado = df_manipulado.drop_duplicates(subset='Movie Name', keep='first')

# %%
# Confirmação de não haver duplicados nos nomes de filmes.

df_manipulado[df_manipulado['Movie Name'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Movie Name, Year of Release, Watch Time, Movie Rating, Description]
# Index: []

# %% [markdown]
# ##### Ordenação da base de dados

# %%
# --- Ordenar a base de dados por ordem alfabética no Nome dos filmes --- #

# Ordenou-se a base de dados por ordem alfabética do nome dos filmes com o indice a ser reiniciado.

df_manipulado.sort_values(by='Movie Name', inplace= True, ignore_index= True)

# %% [markdown]
# ### Criação do ficheiro final

# %%
# --- Guardar a base de dados limpa num ficheiro para utilizar --- #

# Guardaram-se todos os dados menos a coluna do indice.

df_manipulado.to_csv('filmes_imdb.csv', index= False)
